# %%
import numpy as np
import pandas as pd

# %%
# Read the CSV file
data = pd.read_csv('bank_marketing.csv')
data
# Out:
#       client_id   age          job   marital    education credit_default  \
# 0         32884   NaN          NaN   married          NaN             no
# 1          3169  55.0      unknown   married      unknown        unknown
# 2         32206  33.0  blue-collar   married     basic.9y             no
# 3          9403   NaN          NaN   married          NaN             no
# 4         14020  27.0    housemaid   married  high.school             no
# ...         ...   ...          ...       ...          ...            ...
# 9780      40291   NaN          NaN  divorced          NaN             no
# 9781       1412   NaN          NaN  divorced          NaN             no
# 9782      26188   NaN          NaN   married          NaN             no
# 9783      18326   NaN          NaN   married          NaN             no
# 9784      39909   NaN          NaN    single          NaN             no
#
#      mortgage month  day  contact_duration  number_contacts  \
# 0          no   may    9               371                1
# 1         yes   may   24               285                2
# 2          no   may    1                52                1
# 3          no   jun    3               355                4
# 4         yes   jul   30               189                2
# ...       ...   ...  ...               ...              ...
# 9780       no   jul   21               169                2
# 9781      yes   may    5               453                2
# 9782      yes   nov    2               348                3
# 9783      yes   jul    7               962                4
# 9784      yes   jun    6               193                1
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              1          failure          92.893
# 1                              0      nonexistent          93.994
# 2                              1          failure          92.893
# 3                              0      nonexistent          94.465
# 4                              0      nonexistent          93.918
# ...                          ...              ...             ...
# 9780                           2          success          94.215
# 9781                           0      nonexistent          93.994
# 9782                           0      nonexistent          93.200
# 9783                           0      nonexistent          93.918
# 9784                           1          failure          94.055
#
#       euribor_three_months campaign_outcome
# 0                    1.299               no
# 1                    4.860               no
# 2                    1.313               no
# 3                    4.967               no
# 4                    4.963               no
# ...                    ...              ...
# 9780                 0.899              yes
# 9781                 4.855               no
# 9782                 4.076               no
# 9783                 4.963              yes
# 9784                 0.739               no
#
# [9785 rows x 16 columns]

# %%
# Check if there are duplicated values in the data set
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9780     True
# 9781     True
# 9782     True
# 9783     True
# 9784     True
# Length: 9785, dtype: bool

# %%
# Remove the duplicates in the dataset which targets the primary key client_id
data = data.drop_duplicates(subset=['client_id'], keep='first').copy()
data
# Out:
#       client_id   age           job   marital          education  \
# 0         32884   NaN           NaN   married                NaN
# 1          3169  55.0       unknown   married            unknown
# 2         32206  33.0   blue-collar   married           basic.9y
# 3          9403   NaN           NaN   married                NaN
# 4         14020  27.0     housemaid   married        high.school
# ...         ...   ...           ...       ...                ...
# 9495      39541  52.0        admin.   married            unknown
# 9496       3921  41.0   blue-collar   married           basic.4y
# 9497      18387  32.0        admin.  divorced        high.school
# 9498      38711  61.0    management   married  university.degree
# 9499       1274  38.0  entrepreneur   married           basic.6y
#
#      credit_default mortgage month  day  contact_duration  number_contacts  \
# 0                no       no   may    9               371                1
# 1           unknown      yes   may   24               285                2
# 2                no       no   may    1                52                1
# 3                no       no   jun    3               355                4
# 4                no      yes   jul   30               189                2
# ...             ...      ...   ...  ...               ...              ...
# 9495             no       no   apr   23               387                2
# 9496        unknown       no   may   29                88                5
# 9497             no  unknown   jul    1                81                4
# 9498             no      yes   nov   28               195                1
# 9499             no      yes   may   14               196                1
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              1          failure          92.893
# 1                              0      nonexistent          93.994
# 2                              1          failure          92.893
# 3                              0      nonexistent          94.465
# 4                              0      nonexistent          93.918
# ...                          ...              ...             ...
# 9495                           0      nonexistent          93.749
# 9496                           0      nonexistent          93.994
# 9497                           0      nonexistent          93.918
# 9498                           1          success          92.649
# 9499                           0      nonexistent          93.994
#
#       euribor_three_months campaign_outcome
# 0                    1.299               no
# 1                    4.860               no
# 2                    1.313               no
# 3                    4.967               no
# 4                    4.963               no
# ...                    ...              ...
# 9495                 0.654              yes
# 9496                 4.858               no
# 9497                 4.968               no
# 9498                 0.715              yes
# 9499                 4.855               no
#
# [9500 rows x 16 columns]

# %%
# Define a mapping of month names to numerical values
month_mapping = {
    'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6,
    'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12
}

# %%
# Add a temporary year column (2022) that will be used for formatting later
data['year'] = 2022

# %%
# Replace month names with numeric values
data['month'] = data['month'].map(month_mapping)
data
# Out:
#       client_id   age           job   marital          education  \
# 0         32884   NaN           NaN   married                NaN
# 1          3169  55.0       unknown   married            unknown
# 2         32206  33.0   blue-collar   married           basic.9y
# 3          9403   NaN           NaN   married                NaN
# 4         14020  27.0     housemaid   married        high.school
# ...         ...   ...           ...       ...                ...
# 9495      39541  52.0        admin.   married            unknown
# 9496       3921  41.0   blue-collar   married           basic.4y
# 9497      18387  32.0        admin.  divorced        high.school
# 9498      38711  61.0    management   married  university.degree
# 9499       1274  38.0  entrepreneur   married           basic.6y
#
#      credit_default mortgage  month  day  contact_duration  number_contacts  \
# 0                no       no      5    9               371                1
# 1           unknown      yes      5   24               285                2
# 2                no       no      5    1                52                1
# 3                no       no      6    3               355                4
# 4                no      yes      7   30               189                2
# ...             ...      ...    ...  ...               ...              ...
# 9495             no       no      4   23               387                2
# 9496        unknown       no      5   29                88                5
# 9497             no  unknown      7    1                81                4
# 9498             no      yes     11   28               195                1
# 9499             no      yes      5   14               196                1
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              1          failure          92.893
# 1                              0      nonexistent          93.994
# 2                              1          failure          92.893
# 3                              0      nonexistent          94.465
# 4                              0      nonexistent          93.918
# ...                          ...              ...             ...
# 9495                           0      nonexistent          93.749
# 9496                           0      nonexistent          93.994
# 9497                           0      nonexistent          93.918
# 9498                           1          success          92.649
# 9499                           0      nonexistent          93.994
#
#       euribor_three_months campaign_outcome  year
# 0                    1.299               no  2022
# 1                    4.860               no  2022
# 2                    1.313               no  2022
# 3                    4.967               no  2022
# 4                    4.963               no  2022
# ...                    ...              ...   ...
# 9495                 0.654              yes  2022
# 9496                 4.858               no  2022
# 9497                 4.968               no  2022
# 9498                 0.715              yes  2022
# 9499                 4.855               no  2022
#
# [9500 rows x 17 columns]

# %%
# Combine year, month, and day into a single date column
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
data
# Out:
#       client_id   age           job   marital          education  \
# 0         32884   NaN           NaN   married                NaN
# 1          3169  55.0       unknown   married            unknown
# 2         32206  33.0   blue-collar   married           basic.9y
# 3          9403   NaN           NaN   married                NaN
# 4         14020  27.0     housemaid   married        high.school
# ...         ...   ...           ...       ...                ...
# 9495      39541  52.0        admin.   married            unknown
# 9496       3921  41.0   blue-collar   married           basic.4y
# 9497      18387  32.0        admin.  divorced        high.school
# 9498      38711  61.0    management   married  university.degree
# 9499       1274  38.0  entrepreneur   married           basic.6y
#
#      credit_default mortgage  month  day  contact_duration  number_contacts  \
# 0                no       no      5    9               371                1
# 1           unknown      yes      5   24               285                2
# 2                no       no      5    1                52                1
# 3                no       no      6    3               355                4
# 4                no      yes      7   30               189                2
# ...             ...      ...    ...  ...               ...              ...
# 9495             no       no      4   23               387                2
# 9496        unknown       no      5   29                88                5
# 9497             no  unknown      7    1                81                4
# 9498             no      yes     11   28               195                1
# 9499             no      yes      5   14               196                1
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              1          failure          92.893
# 1                              0      nonexistent          93.994
# 2                              1          failure          92.893
# 3                              0      nonexistent          94.465
# 4                              0      nonexistent          93.918
# ...                          ...              ...             ...
# 9495                           0      nonexistent          93.749
# 9496                           0      nonexistent          93.994
# 9497                           0      nonexistent          93.918
# 9498                           1          success          92.649
# 9499                           0      nonexistent          93.994
#
#       euribor_three_months campaign_outcome  year       date
# 0                    1.299               no  2022 2022-05-09
# 1                    4.860               no  2022 2022-05-24
# 2                    1.313               no  2022 2022-05-01
# 3                    4.967               no  2022 2022-06-03
# 4                    4.963               no  2022 2022-07-30
# ...                    ...              ...   ...        ...
# 9495                 0.654              yes  2022 2022-04-23
# 9496                 4.858               no  2022 2022-05-29
# 9497                 4.968               no  2022 2022-07-01
# 9498                 0.715              yes  2022 2022-11-28
# 9499                 4.855               no  2022 2022-05-14
#
# [9500 rows x 18 columns]

# %%
# Drop unnecessary and temporary columns
data = data.drop(columns=['month', 'year', 'day'])
data
# Out:
#       client_id   age           job   marital          education  \
# 0         32884   NaN           NaN   married                NaN
# 1          3169  55.0       unknown   married            unknown
# 2         32206  33.0   blue-collar   married           basic.9y
# 3          9403   NaN           NaN   married                NaN
# 4         14020  27.0     housemaid   married        high.school
# ...         ...   ...           ...       ...                ...
# 9495      39541  52.0        admin.   married            unknown
# 9496       3921  41.0   blue-collar   married           basic.4y
# 9497      18387  32.0        admin.  divorced        high.school
# 9498      38711  61.0    management   married  university.degree
# 9499       1274  38.0  entrepreneur   married           basic.6y
#
#      credit_default mortgage  contact_duration  number_contacts  \
# 0                no       no               371                1
# 1           unknown      yes               285                2
# 2                no       no                52                1
# 3                no       no               355                4
# 4                no      yes               189                2
# ...             ...      ...               ...              ...
# 9495             no       no               387                2
# 9496        unknown       no                88                5
# 9497             no  unknown                81                4
# 9498             no      yes               195                1
# 9499             no      yes               196                1
#
#       previous_campaign_contacts previous_outcome  cons_price_idx  \
# 0                              1          failure          92.893
# 1                              0      nonexistent          93.994
# 2                              1          failure          92.893
# 3                              0      nonexistent          94.465
# 4                              0      nonexistent          93.918
# ...                          ...              ...             ...
# 9495                           0      nonexistent          93.749
# 9496                           0      nonexistent          93.994
# 9497                           0      nonexistent          93.918
# 9498                           1          success          92.649
# 9499                           0      nonexistent          93.994
#
#       euribor_three_months campaign_outcome       date
# 0                    1.299               no 2022-05-09
# 1                    4.860               no 2022-05-24
# 2                    1.313               no 2022-05-01
# 3                    4.967               no 2022-06-03
# 4                    4.963               no 2022-07-30
# ...                    ...              ...        ...
# 9495                 0.654              yes 2022-04-23
# 9496                 4.858               no 2022-05-29
# 9497                 4.968               no 2022-07-01
# 9498                 0.715              yes 2022-11-28
# 9499                 4.855               no 2022-05-14
#
# [9500 rows x 15 columns]
